# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Differentiable Maps and Cob Web Plots
#
# So, lets suppose we have a map $f \in C^{1}(I)$, where $I$ is some interval of the real line.  Unlike with our example involving $C_{3,1}(x)$, it is not such a simple thing to establish for an arbitrary map what happens to a point $x_{0}\in I$ as we iterate with $f(x)$.
#
# To help us in this endeavour, we fall back on graphical and analytic tricks to provide insight.  To wit, we start our study with the concept of a fixed point.
#
# > **Fixed Point of a Map**: We say a point $x_{\ast}\in I$ is a fixed point of $f$ if $f(x_{\ast}) = x_{\ast}$.
#
# Now, what we can do with this is help us characterize what occurs nearby a fixed point.  To wit, suppose that
#
# $$
# \left|f'(x_{\ast})\right| < 1.
# $$
#
# Now, suppose that $x_{0}\in I$, and $x_{0}$ starts _ close _ to $x_{\ast}$.  Since $f'(x)$ is assumed continuous on $I$, and we started _ close _ to $x_{\ast}$, then we can suppose that $|f'(x)|\leq M < 1$ for all $x\in (\min(x_{0},x_{\ast}),\max(x_{0},x_{\ast}))$.  So, by the Mean Value Theorem, we then have
#
# $$
# \frac{\left|f(x_{0})-f(x_{\ast}) \right|}{|x_{0}-x_{\ast}|} = \left|f'(\xi) \right|, ~ \xi \in (\min(x_{0},x_{\ast}),\max(x_{0},x_{\ast})).
# $$
#
# Sorry, I know I keep saying I'm going to chill on the analysis, and I really mean it, I will, but we need just a bit more to keep going.  So by the Mean Value Theorem, I mean
#
# **Mean Value Theorem**: For $f \in C([a,b])$, and $f$ differentiable on $(a,b)$, there exists a point $\xi\in(a,b)$ such that
#
# $$
# f'(\xi) = \frac{f(b)-f(a)}{b-a}.
# $$
#
# ![MVT](https://upload.wikimedia.org/wikipedia/commons/9/94/Mittelwertsatz3.svg)
#
#
#
# _ Problem _: From this, letting $x_{n} = f(x_{n-1}) = f^{(n)}(x_{0})$, show that
#
# $$
# 0\leq \left|x_{n} - x_{\ast} \right| \leq M^{n}\left|x_{0} - x_{\ast} \right|
# $$
# and thus
# $$
# \lim_{n\rightarrow \infty} f^{(n)}(x_{0}) = x_{\ast}
# $$
#
# So we see that if for a fixed point $x_{\ast}$ that $\left|f'(x_{\ast})\right|<1$, then there is some non-trivial neighborhood around $x_{\ast}$, say $S(x_{\ast})$ such that if $x_{0}\in S(x_{\ast})$, then
#
# $$
# \lim_{n\rightarrow \infty} f^{(n)}(x_{0}) = x_{\ast}.
# $$
#
# This attractive property of the fixed point makes it _ stable _ i.e. perturbing away from the fixed point does not fundamentally alter the dynamics.  Actually, we should emphasize that what we have really shown in _ asymptotic stability _, i.e. we not only stay close to $x_{\ast}$, but we actually get closer in the limit.
#
# _ Problem _: How would you characterize a fixed point $x_{\ast}$ for which $\left|f'(x_{\ast})\right|>1$?  Note, use the work above to show that there must be a way to chose $x_{0}$ close enough to $x_{\ast}$ such that
#
# $$
# \left|x_{1}- x_{\ast} \right| \geq M |x_{0}-x_{\ast}|, ~ M>1.
# $$
#
# So as we see, if $|f'(x_{\ast})|>1$, then we describe the fixed point as unstable, i.e. there is a neighborhood of nearby points to $x_{\ast}$ that move away from the fixed point.  We also describe the fixed point as repellant.
#
# To illustrate these concepts, we now introduce the idea of a cobweb plot.  So, let's start with our soon to be best friend, the logistic map $L_{\alpha}(x)$, where
#
# $$
# L_{\alpha}(x) = \alpha x(1-x), ~ \alpha > 0.
# $$
#
# We readily see the fixed points of this map are $x_{\ast}=0$ and $x_{\ast} = 1 - 1/\alpha$.  If we then look at
#
# $$
# L'_{\alpha}(x) = \alpha(1-2x),
# $$
#
# then $\left|L'_{\alpha}(0)\right|= |\alpha|<1$, or we have that $x_{\ast}=0$ is stable for $\alpha<1$.  Likewise,
#
# $$
# \left|L'_{\alpha}\left(1-\frac{1}{\alpha}\right)\right| = \left|\alpha-2\right|,
# $$
#
# so that the other fixed point is unstable if $\alpha<1$ or $\alpha>3$, and stable if $1<\alpha < 3$.  This is also your first example in this class of a bifurcation, but we'll fuss about that in a bit.  So, to understand the impact of all this, we now generate what are called _ cobweb plots _.

# %%
def log_cobweb(x0,aval,niter):
    xvals = np.linspace(0,1,int(1e4))
    yvals = aval*xvals*(1.-xvals)
    
    #Plot the logistic function
    plt.plot(xvals,yvals,ls='--',color='k')
    
    #Plot the line y=x
    plt.plot(xvals,xvals,ls='--',color='k')
    
    La = lambda x: aval*x*(1.-x)
    x1 = La(x0) 
    for jj in xrange(0,niter):
        plt.plot([x0,x0],[x0,x1],color='k')
        plt.plot([x0,x1],[x1,x1],color='k')
        x0 = x1
        x1 = La(x0)
        
    plt.xlim((0.,1.))
    plt.ylim((0.,aval/4.+.05))
    plt.xlabel('$x_{n}$')
    plt.ylabel('$x_{n+1}$')

# %%
log_cobweb(.25,3.99,int(5e2))

# %% [markdown]
# ## Periodic Points of Maps
#
# So, at this point, let us now define a periodic point of a map $f(x)$.
#
# > ** Periodic Point **: A point $p$ is a $k$-periodic point of a map $f(x)$ if $f^{(k)}(p)=p$.
#
# Clearly a periodic orbit traces out an orbit along the way, i.e. starting from $p=p_{1}$, we get
#
# $$
# p_{j} = f(p_{j-1}), ~ p_{1} = f(p_{k}), ~ j\geq 2.
# $$
#
# Just as with a fixed point, we can describe the stability of a periodic orbit differentiating $f^{(k)}(x)$ and evaluating at $p$.  We note then that
#
# $$
# f^{(2)}(x) = f(f(x)),
# $$
#
# so that
#
# $$
# \frac{d}{dx}f^{(2)}(x) = f'(f(x))f'(x).
# $$
#
# Thus, for a two cycle, around $p = p_{1}$, we could determine its stability via the formula
#
# \begin{align}
# \frac{d}{dx}f^{(2)}(p_{1}) = & f'(f(p_{1}))f'(p_{2})\\
# = & f'(p_{2})f'(p_{1})
# \end{align}
#
# Thus, we could say a 2-cycle is stable if
#
# $$
# \left|f'(p_{2})f'(p_{1}) \right|<1
# $$
#
# _ Problem _: Generalize this result for a general $k$-cycle.

# %% [markdown]
# ## Covering Theorems for Fixed Points and Cycles of Maps
#
# So, we briefly remind ourselves of the Intermediate Value Theorem for continuous functions.
#
# > ** Intermedaite Value Theorem **: For $f\in C([a,b])$, if $\mbox{min}(f(a),f(b))< c < \mbox{max}(f(a),f(b))$, then there exists a $x\in(a,b)$ such that $f(x)=c$.
#
# The Intermediate Value Theorem is the "can't lift your pencil" rule for continuous functions.  It gives us several interesting results.
#
# > ** Theorem **: If for a given interval $[a,b]$ and continuous function $f$, if $[a,b]\subset f([a,b])$, so that the image of $[a,b]$ covers itself, then there must be at least one fixed point in $[a,b]$.
#
# The proof is quick.  If $f(x)$ is continuous, then so is $f(x)-x$.  Suppose that $f(x)-x>0$ for all $x\in[a,b]$, but then we could not cover $[a,b]$.  Likewise if $f(x)-x<0$.  Thus, there must be a sign change, and so by the Intermediate Value Theorem, there is at least one fixed point in $[a,b]$.
#
# We use this result in chains.  Which is to say, suppose we have a sequence of closed intervals $I_{1}$, $I_{2}$, \cdots, $I_{n}$ such that
#
# $$
# f(I_{1})\supset I_{2}, ~ f(I_{2})\supset I_{3}, \cdots, f(I_{n-1})\supset I_{n}, ~ f(I_{n})\supset I_{1},
# $$
#
# then we have that
#
# $$
# f^{(n)}(I_{1})\supset I_{1},
# $$
#
# and thus we have the existence of an $n$-cycle.
#
# This likewise gives rise to the books notion of a transition graph, which says an arrow can only be drawn from an interval $A$ to $B$ if $f(A)\supset B$.  This let's us make a little more sense of them, and learn some cute things very quickly.  See Example 3.19 starting on page 127 of the text.

# %% [markdown]
# ## Basins of Attraction: Introduction
#
# So, we can also ask the question, given a fixed point, what points are attracted to it, and which points are repelled?  This can be rephrased as asking what is the _ basin of attraction _ for a fixed point $x_{\ast}$, where we define the basin of attraction $B(x_{\ast})$ as
#
# $$
# B(x_{\ast}) = \left\{x\in\mathbb{R}: \lim_{n\rightarrow\infty}f^{(n)}(x) = x_{\ast} \right\}.
# $$
#
# In simple cases, we can come up with definitive answers.  For example, let
#
# $$
# f(x) = ax + b.
# $$
#
# _ Problem _: Show for any $x_{0}\in\mathbb{R}$ that
#
# $$
# f^{(n)}(x_{0}) = a^{n}x_{0} + \frac{a^{n}-1}{a-1}b
# $$
#
# For $a\neq 1$, we have the unique fixed point $x_{\ast} = b/(1-a)$.  For $|a|<1$, show that $B(x_{\ast})=\mathbb{R}$.
#
# Incidentally, if $a=1$, we see that
#
# $$
# f^{(n)}(x_{0}) = x_{0} + nb
# $$
#
# so clearly $a=1$ not only precludes fixed points, but we also just blow up.  However, if $a=-1$, we see that
#
# $$
# f^{(n)}(x_{0}) = \left\{
# \begin{array}{rl}
# x_{0}, & n ~\mbox{even}\\
# b-x_{0}, & n ~ \mbox{odd}
# \end{array}
# \right.
# $$

# %% [markdown]
# In this vein, we can show for $L_{\alpha}(x)$ that if $1<\alpha<3$, if $x_{0}\in(0,1)$, then $x_{n}\rightarrow 1-\frac{1}{\alpha}$. This is not so tricky for $1<\alpha\leq2$.  Let
#
# $$
# x_{\ast}(\alpha) = 1 - \frac{1}{\alpha}.
# $$
#
# Noting that
#
# $$
# L_{\alpha}(x) = x_{\ast}(\alpha) + (2-\alpha)(x-x_{\ast}) - \alpha(x-x_{\ast})^{2},
# $$
#
# we have
#
# \begin{align}
# \left|L_{\alpha}(x) - x_{\ast} \right| = & \left|2-\alpha - \alpha(x-x_{\ast})\right|\left|x-x_{\ast}\right|\\
# =&\left|1-\alpha x\right|\left|x-x_{\ast}\right|,
# \end{align}
#
# and we are always guaranteed to get closer to the fixed point after one iteration if $0< x <2/\alpha$.  Note, we only have $x_{\ast}\in(0,2/\alpha)$ for $1<\alpha<3$, which makes sense.  Given that
#
# $$
# L_{\alpha}:\left[0,1\right] \rightarrow \left[0,\frac{\alpha}{4}\right],
# $$
#
# we see then that for $1<\alpha\leq2$ that this holds true for the entire interval $[0,1]$, so the fixed point attracts every point in $(0,1)$.
#
# For $2 < \alpha < 3$, we see it is a little trickier since now the strictly attracting region $(0,2/\alpha)\subset (0,1)$.  We note though that $2/\alpha > 1/2$ for this range of $\alpha$, and so if $x_{0}\in [2/\alpha,1)$, after one iteration it must necessarily map to a point in $(0,2/\alpha)$.  Thus every point in $(0,1)$ is attracted to $x_{\ast}$ for $1<\alpha<3$.

# %% [markdown]
# So, clearly, if $p$ is a fixed point of a map $f(x)$, it also is a k-cycle for any k.  Thus, when we ask what happens to the dynamics of $L_{\alpha}(x)$ for $\alpha>3$, when we have to stable fixed points anymore, we might ask, do we have a stable 2-cycle.  And the answer is yes, but to show this we have to actually compute the 2-cycle, determine stability, etc...  So we note that
#
# \begin{align}
# L_{\alpha}^{(2)}(x) = & \alpha L_{\alpha}(1-L_{\alpha})\\
# = & \alpha^{2}x(1-x)(1-\alpha x(1-x))\\
# = & -\alpha^{3}x\left(x^{3} + 2x^{2} -\left(1+\frac{1}{\alpha}\right)x + \frac{1}{\alpha}\right)\\
# = & -\alpha^{3}x(x-x_{\ast}(\alpha))(x-p_{1})(x-p_{2}),
# \end{align}
#
# where in the last line we have used the Fundamental Theorem of Algebra.  So at this point, we can effectively do synthetic division to get the result, which is tedious to say the least.
#
# _ Problem _ :You know what to do here. Also see if you can determine the stability of the two cycle.
#
# Anyway, as you can see, this process becomes impossible to carry forward for very much longer.  Thus, we turn to numerical computation.  The idea is the following.  For a range of $\alpha$ values, we are going to iterate $L_{\alpha}(x)$ many, many times, and then look at patterns in say the last quarter of the iterates.

# %%
def bifurc_plt(Nvals,Niter):
    avals = np.linspace(2.9,3.99,int(Nvals))
    x0 = .25*np.ones([int(Niter),int(Nvals)])
    Ncut = int(Niter/16)
    
    for jj in xrange(0,avals.size):
        La = lambda x:avals[jj]*x*(1.-x)
        for kk in xrange(1,Niter):
            x0[kk,jj] = La(x0[kk-1,jj])
            
        plt.scatter(avals[jj]*np.ones([Ncut,1]),x0[15*Ncut:,jj],color='k',marker='.')
    
    fig=plt.gcf() # get current figure
    fig.set_size_inches(9,7) # optional size
    plt.xlabel('$a$')

# %%
bifurc_plt(200,16*200)

# %% [markdown]
# In order to begin to understand this, we need to think a little more formally about itineraries assoicated with maps, or how symbollic dynamics works in a formal sense.  So, we define the space of infinite, two-symbol sequences to be
#
# $$
# \Sigma_{2} = \left\{{\bf s} = \left(s_{0}s_{1}s_{2}\cdots \right), ~ s_{j}=0 ~\mbox{or} ~ 1 \right\}.
# $$
#
# We measure distance between elements of $\Sigma_{2}$ via the metric
#
# $$
# d[{\bf s},{\bf t}] = \sum_{j=0}^{\infty}\frac{\left|s_{j}-t_{j}\right|}{2^{j}}.
# $$
#
# Associated with this is the shift map $\sigma:\Sigma_{2}\rightarrow \Sigma_{2}$, which simply moves a sequence to the left.  Thus
#
# $$
# \sigma({\bf s}) = (s_{1}s_{2}s_{3}\cdots).
# $$
#
# _ Problem _: Show the shift map is continuous with respect to the metric $d$.
#
# As we can see, we can readily characterize the periodic points of $\sigma$ just by repeating a particular finite block and infinite number of times
#
# $$
# {\bf s} = (s_{0}s_{1}\cdots s_{k-1} s_{0}s_{1}\cdots s_{k-1} \cdots),
# $$
#
# so we see
#
# $$
# \sigma^{(k)}({\bf s}) = \left(s_{0}s_{1}\cdots s_{k-1} s_{0}s_{1}\cdots s_{k-1}\cdots\right) = {\bf s}.
# $$
#
# In this vein, we can then show that the set of periodic orbits of $\sigma$ is dense in $\Sigma_{2}$, where again distance is measured with respect to the metric defined above.  Again, by dense, we mean
#
# > ** Dense Subset**: A subset of $\Sigma_{2}$, say $S$, is dense in $\Sigma_{2}$ if for any given ${\bf s}\in\Sigma_{2}$, for all $\epsilon>0$, there exists ${\bf t}\in S$ such that $d[{\bf s},{\bf t}]<\epsilon$.
#
# Thus, a dense subset approximates the full set to an arbitrary degree of precision.  To show the set of periodic orbits are dense in $\Sigma_{2}$, choose an arbitrary sequence ${\bf s}$, where
#
# $$
# {\bf s} = (s_{0}s_{1}s_{2}\cdots s_{n}s_{n+1}\cdots).
# $$
#
# Let
#
# $$
# {\bf t} = (s_{0}s_{1}s_{2}\cdots s_{n}s_{0}s_{1}s_{2}\cdots s_{n}\cdots).
# $$
#
# _ Problem _: Show that
#
# $$
# d[{\bf s},{\bf t}] \leq \frac{1}{2^{n}}.
# $$
